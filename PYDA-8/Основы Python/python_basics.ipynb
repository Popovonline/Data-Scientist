# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# Out:
# 0.2

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
a = len (long_phrase)
b = len (short_phrase)
if a > b:
    print ("Верно")
else: 
    print ("Неверно")
# Out:
# Верно

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
x = int (input("Введите обьем файла в байтах? "))
a = float (x/(2**20))
a = ('{:.2f}'.format(a))
print (f"Объем файла равен {a}Mb")
# Out:
# Введите обьем файла в байтах? 1234567
# Объем файла равен 1.18Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
# Вводим исходные значения:
month = str (input("Введите пожалуйста месяц Вашего рождения: "))
day = int (input("Введите пожалуйста день/число Вашего рождения: "))
print (f"Вы указали месяц - {month}, и день(число) - {day}")

# определяем знак зодиака, согласно исходным данным:
if (21 <= day <= 31 and month == 'Март') or (1 <= day <= 20 and month == 'Апрель'):
    print ("Ваш знак зодиака - ОВЕН")
    
elif (21 <= day <= 30 and month == 'Апрель') or (1 <= day <= 21 and month == 'Май'):
    print ("Ваш знак зодиака - ТЕЛЕЦ")
    
elif (22 <= day <= 31 and month == 'Май') or (1 <= day <= 21 and month == 'Июнь'):
    print ("Ваш знак зодиака - БЛИЗНЕЦЫ")
    
elif (22 <= day <= 30 and month == 'Июнь') or (1 <= day <= 22 and month == 'Июль'):
    print ("Ваш знак зодиака - РАК")
    
elif (23 <= day <= 31 and month == 'Июль') or (1 <= day <= 22 and month == 'Август'):
    print ("Ваш знак зодиака - ЛЕВ")

elif (23 <= day <= 31 and month == 'Август') or (1 <= day <= 22 and month == 'Сентябрь'):
    print ("Ваш знак зодиака - ДЕВА")
    
elif (23 <= day <= 30 and month == 'Сентябрь') or (1 <= day <= 22 and month == 'Октябрь'):
    print ("Ваш знак зодиака - ВЕСЫ")
    
elif (23 <= day <= 31 and month == 'Октябрь') or (1 <= day <= 22 and month == 'Ноябрь'):
    print ("Ваш знак зодиака - СКОРПИОН")
    
elif (23 <= day <= 30 and month == 'Ноябрь') or (1 <= day <= 21 and month == 'Декабрь'):
    print ("Ваш знак зодиака - СТРЕЛЕЦ")
    
elif (22 <= day <= 31 and month == 'Декабрь') or (1 <= day <= 20 and month == 'Январь'):
    print ("Ваш знак зодиака - КОЗЕРОГ")
    
elif (21 <= day <= 31 and month == 'Январь') or (1 <= day <= 19 and month == 'Февраль'):
    print ("Ваш знак зодиака - ВОДОЛЕЙ")
    
elif (20 <= day <= 29 and month == 'Февраль') or (1 <= day <= 20 and month == 'Март'):
    print ("Ваш знак зодиака - РЫБА")
else:
    print ("Вы ввели некорректное знаение месяца или день своего рождения. Попробуйте снова!")
# Out:
# Введите пожалуйста месяц Вашего рождения: Март
# Введите пожалуйста день/число Вашего рождения: 6
# Вы указали месяц - Март, и день(число) - 6
# Ваш знак зодиака - РЫБА

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
# Вводим данные:
salary = int (input("Введите свой ежемесячный доход: "))
loan = int (input ("Введите пожалуйста долю в % - на ипотеку: "))
life = int (input ("Введите пожалуйста долю в % - на жизнь: "))
count = int (input ("Cколько раз приходит премия в год: "))

# Считаем, сколько откладывается на пенсию:
share_retire = (100 - loan - life) / 100;
retire = salary *  share_retire

# Премия                
motivation = salary * count 

# Затраты на Отпуск:
holiday = motivation / 2

# Откладываем часть на вклад:
deposit = motivation / 2

# Считаем сколько было получено и потрачено в разрезе по статьям:
#total_income = (salary * 12) + motivation
#print (f"Общий годовой доход: {total_income}")

total_loan =  (salary * (loan / 100)) * 12
print (f"На ипотеку было потрачено: {total_loan}")

#total_life =  (salary * (life / 100)) * 12
#print (f"На жизнь было потрачено: {total_life}")

total_retire = retire * 12
#print (f"На пенсию было отложено: {total_retire}")

total_savings = deposit + total_retire

print (f"Было накоплено: {total_savings}")
# Out:
# Введите свой ежемесячный доход: 100000
# Введите пожалуйста долю в % - на ипотеку: 30
# Введите пожалуйста долю в % - на жизнь: 50
# Cколько раз приходит премия в год: 2
# На ипотеку было потрачено: 360000.0
# Было накоплено: 340000.0
